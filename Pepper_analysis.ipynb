# %%
import nltk
from collections import Counter
from nltk.corpus import stopwords
from pprint import pprint
from string import punctuation
import numpy as np
from nltk.probability import FreqDist

# %%
sw = stopwords.words('english')

# %%
pepper = open("Sentiment_tweets.txt",'r', encoding = 'UTF-8').read()
pepper_clean = [w for w in pepper.lower().split('\t')]
pepper_clean = [w for w in str(pepper_clean).split()]
pepper_clean = [w for w in pepper_clean if w.isalpha() and w not in sw]
#pepper_clean = [token for tokrn in pepper_clean]

# %%
pepper_clean[:200]
# Out:
# ['charisma',
#  'na',
#  'man',
#  'wey',
#  'return',
#  'teargas',
#  'na',
#  'him',
#  'we',
#  'go',
#  'loyal',
#  'assets',
#  'blockchain',
#  'enthusiast',
#  'too',
#  'many',
#  'proofs',
#  'out',
#  'i',
#  'think',
#  'this',
#  'is',
#  'in',
#  'people',
#  'who',
#  'speak',
#  'up',
#  'are',
#  'or',
#  'being',
#  'killed',
#  'by',
#  'the',
#  'protesters',
#  'are',
#  'being',
#  'shot',
#  'with',
#  'guns',
#  'by',
#  'police',
#  'or',
#  'targeted',
#  'with',
#  'in',
#  'people',
#  'get',
#  'arrested',
#  'for',
#  'facebook',
#  'posts',
#  'or',
#  'for',
#  'showing',
#  'i',
#  'think',
#  'got',
#  'that',
#  'the',
#  'tears',
#  'was',
#  'from',
#  'the',
#  'teargas',
#  'were',
#  'crying',
#  'because',
#  'no',
#  'food',
#  'in',
#  'the',
#  'surprisingly',
#  'often',
#  'i',
#  'think',
#  'someone',
#  'who',
#  'views',
#  'churches',
#  'as',
#  'an',
#  'essential',
#  'human',
#  'right',
#  'would',
#  'teargas',
#  'a',
#  'crowd',
#  'of',
#  'including',
#  'officials',
#  'of',
#  'the',
#  'church',
#  'in',
#  'to',
#  'clear',
#  'out',
#  'the',
#  'area',
#  'so',
#  'he',
#  'can',
#  'do',
#  'a',
#  'a',
#  'little',
#  'a',
#  'lot',
#  'vaccines',
#  'save',
#  'kindness',
#  'does',
#  'blame',
#  'these',
#  'on',
#  'anybody',
#  'but',
#  'i',
#  'said',
#  'what',
#  'i',
#  'where',
#  'is',
#  'the',
#  'where',
#  'is',
#  'did',
#  'he',
#  'call',
#  'someone',
#  'the',
#  'enemy',
#  'of',
#  'the',
#  'sue',
#  'teargas',
#  'shoot',
#  'their',
#  'eyes',
#  'out',
#  'with',
#  'rubber',
#  'appears',
#  'he',
#  'just',
#  'pointed',
#  'out',
#  'that',
#  'he',
#  'has',
#  'a',
#  'contentious',
#  'relationship',
#  'with',
#  'that',
#  'one',
#  'specific',
#  'and',
#  'politely',
#  'at',
#  'on',
#  'of',
#  'those',
#  'same',
#  'people',
#  'cheering',
#  'description',
#  'of',
#  'violent',
#  'national',
#  'guard',
#  'members',
#  'as',
#  'claim',
#  'to',
#  'be',
#  'libertarians',
#  'who',
#  'hate',
#  'and',
#  'say',
#  'they',
#  'need',
#  'guns',
#  'to',
#  'protect',
#  'them',
#  'from',
#  'oppressive',
#  'think',
#  'about',
#  'terrible',
#  'truth',
#  'about',
#  'the',
#  'truth',
#  'is',
#  'that',
#  'if']

# %%
pepper_count = Counter(pepper_clean)
len(pepper_clean)
pepper_fd = FreqDist(pepper_clean)
pepper_fd
# Out:
# FreqDist({'the': 19493, 'to': 13637, 'and': 13275, 'a': 12007, 'of': 9042, 'in': 7439, 'is': 6800, 'with': 6093, 'for': 6026, 'I': 5240, ...})

# %%
print(f"Sentiment is {len(pepper_clean)} tokens long.")
print(f"Sentiment has {len(set(pepper_clean))} unique tokens.")

print(f"Sentiment's lexical diversity is {len(set(pepper_clean))/len(pepper_clean):.3f}.")

# Build a vector of token length
pepper_token_len = [len(w) for w in pepper_clean]

print(f"Sentiment's average token length is {np.mean(pepper_token_len):.2f}.")

pprint(sorted(Counter(pepper_token_len).items()))

print("")
print("All statistics are calculated after normalization and tokenization.")
# Out:
# Sentiment is 250927 tokens long.
# Sentiment has 23161 unique tokens.
# Sentiment's lexical diversity is 0.092.
# Sentiment's average token length is 5.67.
# [(1, 1217),
#  (2, 5548),
#  (3, 25650),
#  (4, 57746),
#  (5, 42812),
#  (6, 36455),
#  (7, 35560),
#  (8, 20471),
#  (9, 10723),
#  (10, 8037),
#  (11, 3473),
#  (12, 1815),
#  (13, 840),
#  (14, 352),
#  (15, 86),
#  (16, 63),
#  (17, 61),
#  (18, 4),
#  (19, 2),
#  (20, 1),
#  (21, 1),
#  (22, 5),
#  (23, 1),
#  (24, 2),
#  (26, 1),
#  (28, 1)]
#
# All statistics are calculated after normalization and tokenization.
